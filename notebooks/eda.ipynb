# %%
# 📌 1. Initial Setting
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Make visualization immediately
# %matplotlib inline

# 📌 2. Read data
df = pd.read_csv("../data/melb_housing.csv")  # 경로 확인!
print(f"Dataset shape: {df.shape}")
df.head()
# Out:
# Dataset shape: (13580, 21)
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
# ...

# %%
# Visualize number of missing values
plt.figure(figsize=(12,6))
df.isnull().sum().sort_values(ascending=False).plot(kind='bar')
plt.title("Missing values per column")
plt.show()

# %%
# Price Distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['Price'], bins=50, kde=True)
plt.title('Price Distribution')
plt.xlabel('Price')
plt.show()

# Building Area Distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['BuildingArea'].dropna(), bins=50, kde=True)
plt.title('Building Area Distribution')
plt.xlabel('Area')
plt.show()

# %%
# Extract numerical variables
num_df = df.select_dtypes(include=[np.number])

# Correlation matrix
corr = num_df.corr()

# Visualize correlation matrix
plt.figure(figsize=(12,10))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Feature Correlation Matrix")
plt.show()

# %%
# Summary of important statistics
df.describe()

# Predictive candidate columns
print(df.columns.tolist())
# Out:
# ['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG', 'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude', 'Longtitude', 'Regionname', 'Propertycount']
